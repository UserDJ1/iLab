# %% [markdown]
# # <font color='red'>DJ Pelletier</font>
# ### <font color='red'>Originally Submitted 9/1/2023</font>
# ### <font color='red'>Resubmitted 9/11/2023</font>
# # <font color='green'>iLab Assignment 01</font>
# ##  <font color='orange'>Due 10 am Friday 1 September 2023</font>
# Please write your solutions in this notebook; using LaTeX where needed to typset mathematical ideas. Please write your solution using a mix of markdown cells and code cells. For this Assignment, please use the Julia Language [Plots.jl](https://docs.juliaplots.org/stable/) package or, if you are only falimiar with python, the [matplotlib](https://matplotlib.org) package.

# %% [markdown]
# ## <font color='purple'>Question 1</font>
# Rewrite following results in their clearest forms, with suitable numbers of significant digits.  <br>
# a. measured height $h = 2.091\pm 0.04329$ m <br>
# b. measured time $t = 1.5432\pm 1.01$ s <br>
# c. measured charge $q = (- 3.21 \times 10^{-18}\pm 2.67\times10^{−20})\,\mathrm{C}$ <br>
# d. measured distance $d = 0.000\,000\,563 \pm 0.000\,000\,07$ m <br>
# e. measured momentum $p = 3.267\times 10^{3} \pm 64$ g cm/s <br>

# %% [markdown]
# ### <font color='green'>Q1 Answers</font>

# %% [markdown]
# a. Measured height $h = (2.091 \pm 0.043)m$\
# <font color='red'> b. Measured time $t = (1.54 \pm 1.01)s$</font> <br>
# b. Measured time $t = (1.5 \pm 1.0)s$
# c. Measured charge $q = (-3.21 \pm 0.03)\times 10^{-18}C$<br>
# d. Measured distance$d = (5.6 \pm 0.7) \times 10^{-7}m$ <br>
# <font color='red'> e. Measured momentum $p = (3267 \pm 64) \frac{g\ cm}{s}$ or: $3270 \pm 60\; \mathrm{g\,cm/s}$ </font><br>
# e. Measured momentum $p = (3270 \pm 60) \frac{g\ cm}{s}$

# %% [markdown]
# ## <font color='purple'>Question 2</font>
# A student measures the density of a liquid five times and obtains <br>
# (in units of g/cm$^3$): 1.8, 2.0, 1.9, 1.7, 1.8 <br>
# a. What would you suggest as values for best estimate and uncertainty for the density?<br>
# b. The student is told that the accepted value is $1.85\;\mathrm{g/cm}^3$. What is the discepancy<br>
# (in g/cm$^3$) between the student's best estimate and the accepted value?<br>
# c. Do you think the discrepancy is significant? Explain!<br>
# d. Calculate the RMS deviation and the standard deviation for these measurements using the Statistics.jl package.<br>

# %% [markdown]
# ### <font color='green'>Q2 Answers</font>

# %% [markdown]
# a. Density $\rho = (1.8 \pm 0.1) \frac{g}{cm^3}$\
# <br>
# <font color='red'> b. The discrepancy between the accepted and measured values is $0.05 \frac{g}{cm^3}$.</font>\
# b. The unrounded value is $\rho = 1.84 \frac{g}{cm^3}$, so the discrepancy between the accepted and measured values is $0.01 \frac{g}{cm^3}$.
# <br>
# c. This is not significant as it is within the error of the measured value. The measured value is not as exact as the accepted value because the measurements were not made precisely enough for the accepted value to be obtained.

# %% [markdown]
# d.

# %%
using Statistics

σsamp = Statistics.std([1.8, 2.0, 1.9, 1.7, 1.8], corrected=true)
σpop = Statistics.std([1.8, 2.0, 1.9, 1.7, 1.8], corrected=false)

println(σsamp)
println(σpop)
# Out:
# 0.11401754250991379
# 0.10198039027185568

# %% [markdown]
# RMS Deviation (Population Standard Deviation) $\sigma_{pop} = 0.10$\
# Sample Standard Deviation $\sigma_{samp} = 0.11$

# %% [markdown]
# ## <font color='purple'>Question 3</font>
# Using Julia do the following:<br>
#
# a. create an array of $N = 10,000$ fake density values, $\rho$, Gaussianly disitributed<br>
# about a mean of $\mu = 1.85$ with a $\sigma=0.20$  (in units of g/cm$^3$) <br>
#
# b. Using Plots.jl, make a histogram showing the array values.<br> Have each bin of the histogram have width 0.01 g/cm$^3$.<br>
#
# c. Make sure the x-axis of your plot has an appropriate axis label with units.<br>
#
# d. Create another array of 10,000 fake density values;<br>
# this time with mean 1.90 and standard deviation 0.10.
#
# e. Make a new plot with both sets of fake data displayed. <br>
# Change the transparency of the plots so that you can see <br>
# both histograms. Make one histogram using red bars and the<br>
# other using green bars.<br>

# %% [markdown]
# ### <font color='green'>Q3 Answers</font>

# %% [markdown]
# a.

# %%
using Plots, Distributions, Random
### Can add LaTeX to plots by loading the LaTeXStrings package
d = Normal(1.85, 0.2)

densityvals = rand(d, 10000);

# %% [markdown]
# b. & c.

# %%
histogram(densityvals, bins=0.6:0.01:3)
title!("Density distribution")
xlabel!("Density (g/cm^3)")
ylabel!("Frequency")

# %% [markdown]
# d.

# %%
d2 = Normal(1.9, 0.1)

densityvals2 = rand(d2, 10000);

# %% [markdown]
# e.

# %%
histogram([densityvals, densityvals2], fillcolor=[:green :red], fillalpha=0.5, label=["Distribution 1" "Distribution 2"], legend=:topright, bins=0.6:0.01:3)
title!("Density distributions")
xlabel!("Density (g/cm^3)")
ylabel!("Frequency")

# %% [markdown]
# ## <font color='purple'>Question 4</font>
# If I measure the radius of a sphere as $ r = 2.0 \pm 0.1$ m,<br>
# what should I report for the sphere’s volume? Make sure in your answer that you <br>
# a. use \LaTeX to  differential error propagation to compute the uncertainty in the volume<br>
# (i.e. I should see the \LaTeX typeset
# reasoning leading to your answer), and<br>
# b. report your answer as a volume $\pm$ and uncertainty.

# %% [markdown]
# ### <font color='green'>Q4 Answer</font>

# %%
using Measurements

r = 2.0 ± 0.1

v = (4/3)*π*r^3
# Out:
# 33.5 ± 5.0

# %% [markdown]
# Volume of the sphere $v = \frac{4}{3}\pi r^3 = 33.5 \pm 5.0 \ m^3$\
# \
# Volume uncertainty $\Delta v = v\sqrt{\left(\frac{3\Delta r}{r}\right)^2} = (33.5m^3)\left|\frac{(3)(0.1m)}{2.0m}\right| = 5.0m^3$

# %% [markdown]
# ## <font color='purple'>Question 5</font>
# Suppose that you measure two independent variables as<br>
# $x=6.00 \pm 0.12 \;\mathrm{and}\; y = 3.14 \pm 0.08$.<br>
# Use these values to calculate $q = xy + x^3/y$. What will be your answer and its uncertainty?<br>
# For this problem write your answer using <br>
# a. a hand calculation typeset using $\LaTeX$ in a markdown cell, and <br>
# b. a Julia code cell which invokes the [Measurements.jl](https://github.com/JuliaPhysics/Measurements.jl) package to compute $q \pm \Delta q$

# %% [markdown]
# ### <font color='green'>Q5 Answers</font>

# %% [markdown]
# ###  <font color='red'>   This method is incorrect since the function q is not a simple product of powers. FIX!</font> <br>
# Uncertainty in $q$,$\\\Delta q = \sqrt{\left(\frac{\partial q}{\partial x}\right)^2\Delta x^2 + \left(\frac{\partial q}{\partial y}\right)^2\Delta y^2} = \sqrt{\left(y + \frac{3x^2}{y}\right)^2\Delta x^2 + \left(x - \frac{x^3}{y^2}\right)^2\Delta y^2} = \sqrt{\left(3.14 + \frac{3(6.00)^2}{3.14}\right)^2(0.12)^2 + \left(6.00 - \frac{6.00^3}{3.14^2}\right)^2(0.08)^2} \approx 4.7$

# %%
x = 6.00 ± 0.12;
y = 3.14 ± 0.08;

# %%
q = x*y + x^3/y
# Out:
# 87.6 ± 4.7

# %% [markdown]
# <font color='yellow'>Old commentary:</font>
#
# I am not sure why my answer does not agree with Measurement.jl's.\
# $q = a + b$ follows the following formula for error propogation: $\Delta q = \Delta a + \Delta b$. In this case, $a = xy$, therefore $\Delta a = xy\sqrt{\left(\frac{\Delta x}{x}\right)^2 + \left(\frac{\Delta y}{y}\right)^2}$. $b = \frac{x^3}{y}$, therefore $\Delta b = \frac{x^3}{y}\sqrt{\left(\frac{3\Delta x}{x}\right)^2 + \left(\frac{-\Delta y}{y}\right)^2}$.

# %% [markdown]
# ## <font color='purple'>Question 6</font>
# If a stone is thrown vertically upward with speed $v$, it should rise to a height $h$ given by $v^2 = 2gh$. In particular, $v^2$ should be proportional to $h$. To test this proportionality, a student on Planet X measures $v^2$ and $h$ for seven different throws and obtains the results shown here:
#
# | $h$             | $v^2$               |
# |-----------------|---------------------|
# | $\left (\,\pm\, 0.05\,\mathrm{m}\right )$  | $\left (\,\pm 3\,\mathrm{m}^2/\mathrm{s}^2\right )$     |
# | $0.40$          | $7$                 |
# | $0.80$          | $17$                |
# | $1.4$           | $25$                |
# | $2.0$           | $38$                |
# | $2.6$           | $45$                |
# | $3.4$           | $62$                |
# | $3.8$           | $72$                |
#
# a. Make a plot of $v^2$ vs $h$, including vertical and horizontal error bars using either As usual, label your axes, and scale the axes suitably. Is your plot consistent with the prediction that $v^2 \propto h$?<br>
#
# b. The slope of your graph should be $2g$. To find the slope, draw the best fit straight line by performing a linear fit to the data.
# Use the [LsqFit.jl](https://github.com/JuliaNLSolvers/LsqFit.jl) package to do this. What is your experimental value of the slope and it's $1\sigma$ uncertainty?

# %% [markdown]
# ### <font color='green'>Q6 Answers</font>

# %% [markdown]
# a.

# %%
h = [0.40 ± 0.05, 0.80 ± 0.05, 1.4 ± 0.05, 2.0 ± 0.05, 2.6 ± 0.05, 3.4 ± 0.05, 3.8 ± 0.05];
vsquared = [7 ± 3, 17 ± 3, 25 ± 3, 38 ± 3, 45 ± 3, 62 ± 3, 72 ± 3];

# %% [markdown]
# ###  <font color='red'> In the cell below, do not connect points by discontinuous sloped segments. Why?</font>
#
# Because the line segments may not properly represent the behavior of the data.

# %%
plot(scatter(h, vsquared), legend=false)
title!("\$v^2\$ vs \$h\$")
xlabel!("\$h\$ (\$m\$)")
ylabel!("\$v^2\$ (\$m^2/s^2\$)")

# %% [markdown]
# This plot appears consistent with the linear relationship between $v^2$ and $h$.\
# \
# b.

# %%
using LsqFit

#@. model(x, p) = p[1]*x
model(x, p) = p[1]*x

fit = curve_fit(model, [e.val for e in h], [e.val for e in vsquared], [19.6]);

# %%
m = coef(fit)[1]
# Out:
# 18.441295546558706

# %%
line(x) = m*x
# Out:
# line (generic function with 1 method)

# %% [markdown]
# ###  <font color='red'> In the cell below, do not connect points by discontinuous sloped segments. </font>

# %%
plot(scatter(h, vsquared, label="Experimental data"))
plot!([e.val for e in h], line.([e.val for e in h]), label="Best fit line", seriesalpha=0.5, color="red", linestyle=:dash)
title!("\$v^2\$ vs \$h\$ experimental data with best fit line")
xlabel!("\$h\$ (\$m\$)")
ylabel!("\$v^2\$ (\$m^2/s^2\$)")

# %%
sigma = stderror(fit)[1]
# Out:
# 0.2903053274493938

# %% [markdown]
# The best fit line is $v' \approx 18.4h$.\
# The $1\sigma$ error on the slope is $0.3$.
